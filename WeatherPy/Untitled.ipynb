# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

record = 1

print(f"Beginning Data Retrieval")
print(f"------------------------")

for city in cities:  
    try: 
        response = requests.get(f"{url}&q={city}").json()  
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        record= record + 1
        
        time.sleep(1.01)
        
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2042807a0dd790b7ee58363d8cb65da&q=atuona
# City not found. Skipping...
# Processing Record 2 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2042807a0dd790b7ee58363d8cb65da&q=dikson
# Processing Record 3 | Baracoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2042807a0dd790b7ee58363d8cb65da&q=baracoa
# Processing Record 4 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2042807a0dd790b7ee58363d8cb65da&q=gat
# Processing Record 5 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2042807a0dd790b7ee58363d8cb65da&q=clyde river
# Processing Record 6 | Severo-Yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2042807a0dd790b7ee58363d8cb65da&q=severo-yeniseyskiy
# ...

# %%
weather_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

output_data_file = pd.DataFrame(weather_dict)

output_data_file.count()
# Out:
# City          537
# Cloudiness    537
# Country       537
# Date          537
# Humidity      537
# Lat           537
# Lng           537
# Max Temp      537
# Wind Speed    537
# dtype: int64

# %%
output_data_file.to_csv('output/cities.csv')

output_data_file.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Atuona           2      PF  1573948850        70  -9.80 -139.03
# 1       Dikson           0      RU  1573948788        87  73.51   80.55
# 2      Baracoa          58      CU  1573948852        74  20.35  -74.50
# 3          Gat          98      SN  1573948853        83  14.69  -16.54
# 4  Clyde River           1      CA  1573948851        77  70.47  -68.59
#
#    Max Temp  Wind Speed
# 0     80.11       13.56
# 1    -11.42        9.17
# 2     81.27        0.76
# 3     75.20        6.93
# 4      3.20       13.87

# %%
plt.scatter(output_data_file["Lat"], output_data_file["Max Temp"], marker="o", s=10)

plt.title("Latitude vs Max Temp")
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output/Max_Temp_vs_Latitude.png")

plt.show()

# %%
plt.scatter(output_data_file["Lat"], output_data_file["Humidity"], marker="o", s=10)

plt.title("Latitude vs Humidity")
plt.ylabel("Humidity Pct.")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output/Humidity_vs_Latitude.png")

plt.show()

# %%
plt.scatter(output_data_file["Lat"], output_data_file["Cloudiness"], marker="o", s=10)

plt.title("Latitude vs Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output/Cloudiness_vs_Latitude.png")

plt.show()

# %%
plt.scatter(output_data_file["Lat"], output_data_file["Wind Speed"], marker="o", s=10)

plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output/Wind_Speed_vs_Latitude.png")

plt.show()
